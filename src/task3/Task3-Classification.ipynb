# %% [markdown]
# # Task 3 : Classification (Part A of Dimensionality Reduction)
# ***
# This notebook contains the process with which the classifiers were built for this task.
# It is long and detailed. Refer to the Short version of this notebook for a simpler, direct solution to the task at hand.
# ***
# By : [Naimish Mani B](https://www.github.com/Naimish240)
# ***
# # TOC
# * [Preface](#pre)
# * [Generator](#gen)
# * [Understanding  the dataset](#vis)
#     - [Basic properties](#prop)
#     - [Standard Deviation](#stdv)
# * [Pre requisites](#preq)
#     - [Train-Test Split](#tts)
#     - [Evaluation Metric](#roc)
#     - [SGD](#sgd)
# * [Classification without sklearn](#class)
#     - [Logistic Regression](#reg)
#     - [K-Nearest Neighbours](#knn)
#     - [Decision Trees](#dt)
#     - [Random Forest](#rf)
#     - [RBF Support Vector Machine](#rbf)
#     - [Naive Bayes Classifier](#nb)
#     - [Artificial Neural Network](#ann)
#     - [AdaBoost](#ada)
# * [Concluding thoughts](#conc)
# ***
# # **Preface** <a class="anchor" id="pre"></a>
#
# Initially, I considered using scikit-learn to run all the above classifiers with. But after extracting the dataset, I realised that I don't have enough memory to load the entire dataset. This is a problem, because all sklearn functions require the entire dataset to be loaded into memory. Hence, in an attempt to circumvent this issue, I ended up implementing my own generator to yield the data one line at a time, and also wrote my own classifiers to work with this method.
#
# This is just a starting point, though. There are a couple of issues with the method I've adopted. For one, it loads elements into memory sequentially. This is a problem wherever we use batches, because we cannot gurantee there being a good, uniform split of elements from each class in the batch. This might lead to accuracy issues. But it can be mitigated by performing random access on the file, by maybe using seek() to read a specific line in the file, and then randomly reading the lines to make the training set. This might ensure uniformity across batches.
#
# <!--I ended up freeing up ram on my device through non-conventional techniques. I disabled GUI and killed all extra processes, and ssh'ed into it from another device, started up a Jupyter server and loaded the entire dataset into memory.-->

# %%
# Import statements
import matplotlib.pyplot as plt
from time import time
from math import sqrt

# %% [markdown]
# ***
# # **Generator** <a class="anchor" id="gen"></a>
#
# As was mentioned above, I don't have enough memory to load the whole data set. So, the logical thing to do is to load in each row at a time.
#
# We load the file in the `getRow` generator, which in turn yields us one row from the dataset. Next, we also define a function `getBatch` to yield batches of size SIZE.
#
# The code for these functions can be found below.

# %%
# Generator, because I don't have enough memory to load the dataset fully

# Converts the read line into a list for further processing
def processLine(l):
    '''
    Input:
        l : line to convert into array
        
    Output:
        l : numpy array, after conversion
    '''
    l = l.split(',')
    l = [float(i) for i in l]
    return l

# Generator to yield each row at a time
def getRow():
    '''
    Output:
        Generator object, yields each row
    '''
    with open('../../HIGGS_6M.csv', 'r') as fh: # Replace with path to dataset locally
        try:
            while True:
                line = fh.readline()
                # print(line)
                row = processLine(line)
                # print(row)
                yield row
        # End of file reached
        except:
            return None

# Generator to yield a batch at a time
def getBatch(SIZE):
    try:
        while True:
            x = getRow()
            i = 0
            batch = []
            while i < SIZE:
                row = next(x)
                batch.append(row)
                i += 1
            yield batch
    # EoF
    except:
        return None

# %%
# Test generator to see if it works
x = getRow()
print(next(x))
print(next(x))
# Deleting the generator, because we don't want any memory leaks
del x
# Out:
# [1.0, 0.869293212890625, -0.6350818276405334, 0.22569026052951813, 0.327470064163208, -0.6899932026863098, 0.7542022466659546, -0.24857313930988312, -1.0920639038085938, 0.0, 1.3749921321868896, -0.6536741852760315, 0.9303491115570068, 1.1074360609054565, 1.138904333114624, -1.5781983137130737, -1.046985387802124, 0.0, 0.657929539680481, -0.010454569943249226, -0.0457671694457531, 3.101961374282837, 1.353760004043579, 0.9795631170272827, 0.978076159954071, 0.9200048446655273, 0.7216574549674988, 0.9887509346008301, 0.8766783475875854]
# [1.0, 0.9075421094894409, 0.3291472792625427, 0.3594118654727936, 1.4979698657989502, -0.3130095303058624, 1.09553062915802, -0.5575249195098877, -1.588229775428772, 2.1730761528015137, 0.8125811815261841, -0.2136419266462326, 1.2710145711898804, 2.214872121810913, 0.4999939501285553, -1.2614318132400513, 0.7321561574935913, 0.0, 0.39870089292526245, -1.138930082321167, -0.0008191101951524615, 0.0, 0.3022198975086212, 0.8330481648445129, 0.9856996536254883, 0.9780983924865723, 0.7797321677207947, 0.9923557639122009, 0.7983425855636597]

# %%
# Test batch generator to see if it works
x = getBatch(2)
print(next(x))
# Delete generator
del x
# Out:
# [[1.0, 0.869293212890625, -0.6350818276405334, 0.22569026052951813, 0.327470064163208, -0.6899932026863098, 0.7542022466659546, -0.24857313930988312, -1.0920639038085938, 0.0, 1.3749921321868896, -0.6536741852760315, 0.9303491115570068, 1.1074360609054565, 1.138904333114624, -1.5781983137130737, -1.046985387802124, 0.0, 0.657929539680481, -0.010454569943249226, -0.0457671694457531, 3.101961374282837, 1.353760004043579, 0.9795631170272827, 0.978076159954071, 0.9200048446655273, 0.7216574549674988, 0.9887509346008301, 0.8766783475875854], [1.0, 0.9075421094894409, 0.3291472792625427, 0.3594118654727936, 1.4979698657989502, -0.3130095303058624, 1.09553062915802, -0.5575249195098877, -1.588229775428772, 2.1730761528015137, 0.8125811815261841, -0.2136419266462326, 1.2710145711898804, 2.214872121810913, 0.4999939501285553, -1.2614318132400513, 0.7321561574935913, 0.0, 0.39870089292526245, -1.138930082321167, -0.0008191101951524615, 0.0, 0.3022198975086212, 0.8330481648445129, 0.9856996536254883, 0.9780983924865723, 0.7797321677207947, 0.9923557639122009, 0.7983425855636597]]

# %% [markdown]
# Now that we've got the generator ready, let's move on to visualising the features in the dataset.
# ***
# # **Understanding the Dataset** <a class="anchor" id="vis"></a>
#
# First things first, we check if all 6M rows are present. From the generator, we know that are 29 columns in the dataset. First column is the category the element belongs to, the next 21 columns are basic features, and the final 7 features are functions of the first 21, as mentioned in the question.
#
# # Basic Properties<a class="anchor" id="prop"></a>
#
# To get a basic idea of what the dataset looks like, it makes sense to find the maximum, minimum and average of the columns of the dataset.
#
# Here,
# $$
# \mu = \frac{\Sigma{x_{i}}}{N}
# $$

# %%
t1 = time()
x = getRow()
rows = 0
# Lists to store the properties for each column
maximum = [0] * 29
minimum = [0] * 29
total = [0] * 29

try:
    # While loop to iterate through the dataset
    while True:
        r = next(x)
        rows += 1
        # Iterate through each element in the row to see if we need to update any of the above properties
        for i in range(len(r)):
            # If element is less than minimum
            if r[i] < minimum[i]:
                minimum[i] = r[i]
            # If element is greater than maximum
            if r[i] > maximum[i]:
                maximum[i] = r[i]
            # Add element to total, to find average
            total[i] += r[i]
except:
    print("Iterated through ", rows, "rows")

# Calculate average
mu = [i/rows for i in total]

for i in range(29):
    print("-----------------------------")
    print(i+1, "th column properties")
    print("Maximum element: ", maximum[i])
    print("Minimum element: ", minimum[i])
    print("Sum of all elements: ", total[i])
    print("Average value of column: ", mu[i])
print("-----------------------------")
print("Execution took ", time()-t1, "s")
# Out:
# Iterated through  6000000 rows
# -----------------------------
# 1 th column properties
# Maximum element:  1.0
# Minimum element:  0
# Sum of all elements:  3178345.0
# Average value of column:  0.5297241666666667
# -----------------------------
# 2 th column properties
# Maximum element:  10.396014213562012
# Minimum element:  0
# Sum of all elements:  5946832.861814141
# Average value of column:  0.9911388103023568
# -----------------------------
# 3 th column properties
# Maximum element:  2.4348678588867188
# Minimum element:  -2.434976100921631
# Sum of all elements:  -37.90278963888704
# Average value of column:  -6.317131606481174e-06
# -----------------------------
# 4 th column properties
# Maximum element:  1.7432359457015991
# Minimum element:  -1.7425082921981812
# Sum of all elements:  2179.9233033626515
# Average value of column:  0.0003633205505604419
# -----------------------------
# 5 th column properties
# Maximum element:  15.396821022033691
# Minimum element:  0
# Sum of all elements:  5989140.586218525
# Average value of column:  0.9981900977030874
# -----------------------------
# 6 th column properties
# Maximum element:  1.7432570457458496
# Minimum element:  -1.7439435720443726
# Sum of all elements:  191.42729802763472
# Average value of column:  3.190454967127245e-05
# -----------------------------
# 7 th column properties
# Maximum element:  8.848615646362305
# Minimum element:  0
# Sum of all elements:  5945316.067786321
# Average value of column:  0.9908860112977201
# -----------------------------
# 8 th column properties
# Maximum element:  2.9696741104125977
# Minimum element:  -2.9697251319885254
# Sum of all elements:  -3217.0929215975484
# Average value of column:  -0.0005361821535995914
# -----------------------------
# 9 th column properties
# Maximum element:  1.741453766822815
# Minimum element:  -1.7412374019622803
# Sum of all elements:  -536.4226136379366
# Average value of column:  -8.94037689396561e-05
# -----------------------------
# 10 th column properties
# Maximum element:  2.1730761528015137
# Minimum element:  0
# Sum of all elements:  6002983.795240402
# Average value of column:  1.0004972992067338
# -----------------------------
# 11 th column properties
# Maximum element:  11.64708137512207
# Minimum element:  0
# Sum of all elements:  5954836.827848464
# Average value of column:  0.9924728046414107
# -----------------------------
# 12 th column properties
# Maximum element:  2.913209915161133
# Minimum element:  -2.9130895137786865
# Sum of all elements:  2233.3701508313934
# Average value of column:  0.0003722283584718989
# -----------------------------
# 13 th column properties
# Maximum element:  1.7431747913360596
# Minimum element:  -1.742371678352356
# Sum of all elements:  -1220.633285110598
# Average value of column:  -0.00020343888085176635
# -----------------------------
# 14 th column properties
# Maximum element:  2.214872121810913
# Minimum element:  0
# Sum of all elements:  5996993.294195533
# Average value of column:  0.9994988823659221
# -----------------------------
# 15 th column properties
# Maximum element:  11.423816680908203
# Minimum element:  0
# Sum of all elements:  5952854.309081405
# Average value of column:  0.9921423848469009
# -----------------------------
# 16 th column properties
# Maximum element:  2.730008840560913
# Minimum element:  -2.7296628952026367
# Sum of all elements:  768.9688448131783
# Average value of column:  0.00012816147413552973
# -----------------------------
# 17 th column properties
# Maximum element:  1.7428839206695557
# Minimum element:  -1.7420687675476074
# Sum of all elements:  -1262.268708464704
# Average value of column:  -0.00021037811807745067
# -----------------------------
# 18 th column properties
# Maximum element:  2.548224449157715
# Minimum element:  0
# Sum of all elements:  6001892.928375721
# Average value of column:  1.0003154880626202
# -----------------------------
# 19 th column properties
# Maximum element:  12.882567405700684
# Minimum element:  0
# Sum of all elements:  5915676.82774201
# Average value of column:  0.9859461379570017
# -----------------------------
# 20 th column properties
# Maximum element:  2.498008966445923
# Minimum element:  -2.497264862060547
# Sum of all elements:  329.7330472720496
# Average value of column:  5.495550787867493e-05
# -----------------------------
# 21 th column properties
# Maximum element:  1.7433723211288452
# Minimum element:  -1.7426908016204834
# Sum of all elements:  60.60094377648784
# Average value of column:  1.0100157296081306e-05
# -----------------------------
# 22 th column properties
# Maximum element:  3.101961374282837
# Minimum element:  0
# Sum of all elements:  5997043.638630629
# Average value of column:  0.9995072731051048
# -----------------------------
# 23 th column properties
# Maximum element:  31.076190948486328
# Minimum element:  0
# Sum of all elements:  6205758.422267348
# Average value of column:  1.0342930703778912
# -----------------------------
# 24 th column properties
# Maximum element:  15.637859344482422
# Minimum element:  0
# Sum of all elements:  6148634.813084021
# Average value of column:  1.024772468847337
# -----------------------------
# 25 th column properties
# Maximum element:  7.992739200592041
# Minimum element:  0
# Sum of all elements:  6302430.75761237
# Average value of column:  1.0504051262687284
# -----------------------------
# 26 th column properties
# Maximum element:  14.262438774108887
# Minimum element:  0
# Sum of all elements:  6058401.133418202
# Average value of column:  1.009733522236367
# -----------------------------
# 27 th column properties
# Maximum element:  17.76285171508789
# Minimum element:  0
# Sum of all elements:  5838172.780578401
# Average value of column:  0.9730287967630669
# -----------------------------
# 28 th column properties
# Maximum element:  8.779914855957031
# Minimum element:  0
# Sum of all elements:  6198300.30404377
# Average value of column:  1.0330500506739617
# -----------------------------
# 29 th column properties
# Maximum element:  6.966903209686279
# Minimum element:  0
# Sum of all elements:  5758588.878965914
# Average value of column:  0.9597648131609857
# -----------------------------
# Execution took  80.39320516586304 s

# %% [markdown]
# As we can see here, it takes almost one and a half minutes to iterate through the dataset once.
#
# Now that we have the value for the average of each column, the next thing we would want to do is calculate the variance and standard deviation displayed across each column.
# ***
# *NOTE:*
# 1. *We don't know if there's any missing data present in the table as zeros*
# 2. *If such data exists, we don't know how to distingush the missing elements from elements who's value is actually zero*
#
# *So, we assume the zeros present in the dataset are elements where the value is actually zero, and not cases of missing values.*
# ***
#
# Next, let's calculate the variance and standard deviation of the dataset
#
# ## Formula for Standard Deviation: <a class="anchor" id="stdv"></a>
#
# $$
# \sigma = \sqrt{\frac{\Sigma(x_{i} - \mu)^2}{N}}
# $$

# %%
# Start time
t1 = time()

# Generate again, because we're iterating again
x = getRow()

# List to store variance
variance = [0] * 29

try:
    # While loop to iterate through the dataset
    while True:
        r = next(x)
        # Iterate through each element in the row to calculate it's variance
        for i in range(len(r)):
            variance[i] += (((r[i] - mu[i]) ** 2) / rows)

except:
    print("Iterated through all rows")

# Calculate standard deviation for the column
sd = [sqrt(i) for i in variance]

# Print all properties of each column
for i in range(29):
    print("-----------------------------")
    print(i+1, "th column properties")
    print("Maximum element: ", maximum[i])
    print("Minimum element: ", minimum[i])
    print("Sum of all elements: ", total[i])
    print("Average value of column: ", mu[i])
    print("Variance of column: ", variance[i])
    print("Standard Deviation of column: ", sd[i])
print("-----------------------------")
print("Execution took ", time()-t1, "s")
# Out:
# Iterated through all rows
# -----------------------------
# 1 th column properties
# Maximum element:  1.0
# Minimum element:  0
# Sum of all elements:  3178345.0
# Average value of column:  0.5297241666666667
# Variance of column:  0.24911647393302003
# Standard Deviation of column:  0.49911569193226135
# -----------------------------
# 2 th column properties
# Maximum element:  10.396014213562012
# Minimum element:  0
# Sum of all elements:  5946832.861814141
# Average value of column:  0.9911388103023568
# Variance of column:  0.31910747559135505
# Standard Deviation of column:  0.5648959865243822
# -----------------------------
# 3 th column properties
# Maximum element:  2.4348678588867188
# Minimum element:  -2.434976100921631
# Sum of all elements:  -37.90278963888704
# Average value of column:  -6.317131606481174e-06
# Variance of column:  1.0179089684308118
# Standard Deviation of column:  1.0089147478507843
# -----------------------------
# 4 th column properties
# Maximum element:  1.7432359457015991
# Minimum element:  -1.7425082921981812
# Sum of all elements:  2179.9233033626515
# Average value of column:  0.0003633205505604419
# Variance of column:  1.0126025136310268
# Standard Deviation of column:  1.0062815280183905
# -----------------------------
# 5 th column properties
# Maximum element:  15.396821022033691
# Minimum element:  0
# Sum of all elements:  5989140.586218525
# Average value of column:  0.9981900977030874
# Variance of column:  0.3599341868153116
# Standard Deviation of column:  0.5999451531726142
# -----------------------------
# 6 th column properties
# Maximum element:  1.7432570457458496
# Minimum element:  -1.7439435720443726
# Sum of all elements:  191.42729802763472
# Average value of column:  3.190454967127245e-05
# Variance of column:  1.0125334808652635
# Standard Deviation of column:  1.0062472265130789
# -----------------------------
# 7 th column properties
# Maximum element:  8.848615646362305
# Minimum element:  0
# Sum of all elements:  5945316.067786321
# Average value of column:  0.9908860112977201
# Variance of column:  0.2257012931636241
# Standard Deviation of column:  0.47508030180552013
# -----------------------------
# 8 th column properties
# Maximum element:  2.9696741104125977
# Minimum element:  -2.9697251319885254
# Sum of all elements:  -3217.0929215975484
# Average value of column:  -0.0005361821535995914
# Variance of column:  1.0184642769108467
# Standard Deviation of column:  1.0091899112212956
# -----------------------------
# 9 th column properties
# Maximum element:  1.741453766822815
# Minimum element:  -1.7412374019622803
# Sum of all elements:  -536.4226136379366
# Average value of column:  -8.94037689396561e-05
# Variance of column:  1.011793514406231
# Standard Deviation of column:  1.005879473101142
# -----------------------------
# 10 th column properties
# Maximum element:  2.1730761528015137
# Minimum element:  0
# Sum of all elements:  6002983.795240402
# Average value of column:  1.0004972992067338
# Variance of column:  1.05636671383893
# Standard Deviation of column:  1.0277970197655422
# -----------------------------
# 11 th column properties
# Maximum element:  11.64708137512207
# Minimum element:  0
# Sum of all elements:  5954836.827848464
# Average value of column:  0.9924728046414107
# Variance of column:  0.2500135794311201
# Standard Deviation of column:  0.5000135792467242
# -----------------------------
# 12 th column properties
# Maximum element:  2.913209915161133
# Minimum element:  -2.9130895137786865
# Sum of all elements:  2233.3701508313934
# Average value of column:  0.0003722283584718989
# Variance of column:  1.0191696608473089
# Standard Deviation of column:  1.0095393310056369
# -----------------------------
# 13 th column properties
# Maximum element:  1.7431747913360596
# Minimum element:  -1.742371678352356
# Sum of all elements:  -1220.633285110598
# Average value of column:  -0.00020343888085176635
# Variance of column:  1.0122511957187583
# Standard Deviation of column:  1.0061069504375557
# -----------------------------
# 14 th column properties
# Maximum element:  2.214872121810913
# Minimum element:  0
# Sum of all elements:  5996993.294195533
# Average value of column:  0.9994988823659221
# Variance of column:  1.101242963998694
# Standard Deviation of column:  1.049401240707621
# -----------------------------
# 15 th column properties
# Maximum element:  11.423816680908203
# Minimum element:  0
# Sum of all elements:  5952854.309081405
# Average value of column:  0.9921423848469009
# Variance of column:  0.23760923797589215
# Standard Deviation of column:  0.4874517801546038
# -----------------------------
# 16 th column properties
# Maximum element:  2.730008840560913
# Minimum element:  -2.7296628952026367
# Sum of all elements:  768.9688448131783
# Average value of column:  0.00012816147413552973
# Variance of column:  1.0170725251795496
# Standard Deviation of column:  1.0085001364301096
# -----------------------------
# 17 th column properties
# Maximum element:  1.7428839206695557
# Minimum element:  -1.7420687675476074
# Sum of all elements:  -1262.268708464704
# Average value of column:  -0.00021037811807745067
# Variance of column:  1.0128604288403007
# Standard Deviation of column:  1.0064096724695668
# -----------------------------
# 18 th column properties
# Maximum element:  2.548224449157715
# Minimum element:  0
# Sum of all elements:  6001892.928375721
# Average value of column:  1.0003154880626202
# Variance of column:  1.4251660073788244
# Standard Deviation of column:  1.1938031694457945
# -----------------------------
# 19 th column properties
# Maximum element:  12.882567405700684
# Minimum element:  0
# Sum of all elements:  5915676.82774201
# Average value of column:  0.9859461379570017
# Variance of column:  0.2558431467138864
# Standard Deviation of column:  0.5058093976132575
# -----------------------------
# 20 th column properties
# Maximum element:  2.498008966445923
# Minimum element:  -2.497264862060547
# Sum of all elements:  329.7330472720496
# Average value of column:  5.495550787867493e-05
# Variance of column:  1.0155320212289074
# Standard Deviation of column:  1.0077360870927008
# -----------------------------
# 21 th column properties
# Maximum element:  1.7433723211288452
# Minimum element:  -1.7426908016204834
# Sum of all elements:  60.60094377648784
# Average value of column:  1.0100157296081306e-05
# Variance of column:  1.012761052358419
# Standard Deviation of column:  1.0063602994745067
# -----------------------------
# 22 th column properties
# Maximum element:  3.101961374282837
# Minimum element:  0
# Sum of all elements:  5997043.638630629
# Average value of column:  0.9995072731051048
# Variance of column:  1.9601375299212984
# Standard Deviation of column:  1.4000491169674365
# -----------------------------
# 23 th column properties
# Maximum element:  31.076190948486328
# Minimum element:  0
# Sum of all elements:  6205758.422267348
# Average value of column:  1.0342930703778912
# Variance of column:  0.45335089531034045
# Standard Deviation of column:  0.6733133708091207
# -----------------------------
# 24 th column properties
# Maximum element:  15.637859344482422
# Minimum element:  0
# Sum of all elements:  6148634.813084021
# Average value of column:  1.024772468847337
# Variance of column:  0.1447582976627545
# Standard Deviation of column:  0.38047115220835664
# -----------------------------
# 25 th column properties
# Maximum element:  7.992739200592041
# Minimum element:  0
# Sum of all elements:  6302430.75761237
# Average value of column:  1.0504051262687284
# Variance of column:  0.02691001189834657
# Standard Deviation of column:  0.1640427136399132
# -----------------------------
# 26 th column properties
# Maximum element:  14.262438774108887
# Minimum element:  0
# Sum of all elements:  6058401.133418202
# Average value of column:  1.009733522236367
# Variance of column:  0.15795921795987394
# Standard Deviation of column:  0.39744083579807693
# -----------------------------
# 27 th column properties
# Maximum element:  17.76285171508789
# Minimum element:  0
# Sum of all elements:  5838172.780578401
# Average value of column:  0.9730287967630669
# Variance of column:  0.2762122941977667
# Standard Deviation of column:  0.5255590301743152
# -----------------------------
# 28 th column properties
# Maximum element:  8.779914855957031
# Minimum element:  0
# Sum of all elements:  6198300.30404377
# Average value of column:  1.0330500506739617
# Variance of column:  0.13347029125459536
# Standard Deviation of column:  0.36533586089322706
# -----------------------------
# 29 th column properties
# Maximum element:  6.966903209686279
# Minimum element:  0
# Sum of all elements:  5758588.878965914
# Average value of column:  0.9597648131609857
# Variance of column:  0.09817915558016489
# Standard Deviation of column:  0.31333553194645014
# -----------------------------
# Execution took  70.20736694335938 s

# %% [markdown]
# ***
# From this,
# ```
# 1 th column properties
# Maximum element:  1.0
# Minimum element:  0
# Sum of all elements:  3178345.0
# Average value of column:  0.5297241666666667
# Variance of column:  0.24911647393302003
# Standard Deviation of column:  0.49911569193226135
# ```
# we can see that the dataset is almost equally balanced, as there's a 53-47 percentage split across the classes.
#
# Now that we have a basic understanding of what the dataset looks like, and it's standard properties, we can move onto making classifiers.
#
# # Pre Requisites <a class="anchor" id="preq"></a>
#
# We know that there are two classes in the dataset. So, we can make use of binary classifiers. But before we can go ahead implementing the various algorithms, we need to take care of a couple of things.
#
# ##### 1. **Train-Test splitting** <a class="anchor" id="tts"></a>
#
# We're not shuffling the dataset (reason mentioned in the preface). Also, we've been informed to take the last 500k rows as the test set in the problem statement. So this issue has been addressed.
#
# ##### 2. **Evaluation Metric** <a class="anchor" id="roc"></a>
#
# ROC (Recieving Operation Characteristic) curve is a graph which we use to evaluate the performance of a classifier. It is a plot between the parameters
#
# - True Positive Rate
# - False Positive Rate
#
# This curve is used as an evaluation method to gauge the performance of the model. Classifiers that give curves closer to the top-left corner imply a better performance, with performance decreasing as the curve approaches the 45 degree diagonal. The Area Under this Curve (AUC) also serves as a good evaluation metric about how well the model will perform on new data.
#
# We'll be using the functions present in scikit-learn for this calculation.
#
# ##### 3. **Gradient Descent** <a class="anchor" id="gd"></a>
#
# GD is a popular optimisation technique which us used in both ML and DL to iteratively find the optimum value for parameters to minimise a given cost function. When dealing with batches, we make use of Batch Gradient Descent.

# %% [markdown]
# ## Logistic Regression <a class="anchor" id="reg"></a>
#
# Logistic regression is a very common statistical technique used for binary classification. It's formula is as follows:
#
# $$
# P = \frac{e^{a+bX}}{1 + e^{a+bX}}
# $$
